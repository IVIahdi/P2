# %%
from matplotlib import pyplot as plt
x = [1,2,3,4,5,6]
y = [10,20,30,40,50,60]
plt.plot(x,y)
plt.show()

# l = [True, False]
# x = 6
# print(1<= x <= 5 and 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18084\3517995010.py in <module>
#       2 x = [1,2,3,4,5,6]
#       3 y = [10,20,30,40,50,60]
# ----> 4 plt.plot(x,y, lablel= "A")
#       5 plt.show()
#       6
#
# c:\Users\mahdi\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\Users\mahdi\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
