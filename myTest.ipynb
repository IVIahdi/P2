# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = [10,20,30,40,50,60]
yy = y.copy()
print(yy)
plt.plot(x,y)
plt.show()

# l = [True, False]
# x = 6
# print(1<= x <= 5 and 1)
# Out:
# [10, 20, 30, 40, 50, 60]
